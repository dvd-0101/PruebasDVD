# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# **_2-title.png_** ![Screenshot 2025-05-16 155201.png](data:image/png;base64,...)

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# **_3-intro.png_** ![Screenshot 2025-05-16 160503.png](data:image/png;base64,...)

# %% [markdown]
# **Objectives:**
# * List some of the most popular languages Data Scientists use
# * List some of the mmost popular libraries used in Data Science
# * Show how to execute arithmetic operations

# %% [markdown]
# **_10-objectives.png_** ![Screenshot 2025-05-16 210407.png](data:image/png;base64,...)

# %% [markdown]
# ### Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 1. R
# 1. Julia

# %% [markdown]
# **_4-dslanguages.png_** ![Screenshot 2025-05-16 162650.png](data:image/png;base64,...)

# %% [markdown]
# ## Some of the commonly used libraries used by Data Science include:
# 1. Pandas
# 1. NumPy
# 1. SciPy

# %% [markdown]
# **_5-dslibraries.png_** ![Screenshot 2025-05-16 165430.png](data:image/png;base64,...)

# %% [markdown]
# |Data Science Tools|
# -------------------
# | Jupyter Studio |
# | R Studio       |
# | Visual Studio Code|

# %% [markdown]
# **_6-dstools.png_** ![Screenshot 2025-05-16 202913.png](data:image/png;base64,...)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# **_7-introarithmetic.png_** ![Screenshot 2025-05-16 203621.png](data:image/png;base64,...)

# %% [markdown]
# *This is a simple arithmetic expression to multiply then add integers*

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# **_8-multiplyandaddintegers.png_** ![Screenshot 2025-05-16 204202.png](data:image/png;base64,...)

# %% [markdown]
# _This will convert 200 minutes to hours by dividing by 60_

# %%
minutes = 200
hours = minutes / 60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# **_9-hourstominutes.png_**       ![Screenshot 2025-05-16 205240.png](data:image/png;base64,...)

# %% [markdown]
# ## Author
# David Vilches Herrera

# %% [markdown]
# **_11-authordetails.png_** ![Screenshot 2025-05-16 211035.png](data:image/png;base64,...)
